# %%
from tqdm import tqdm
import time
from pathlib import Path

import numpy as np
import cv2
import matplotlib.pyplot as plt

import sys
sys.path.append("../../")
from ratata.inference.video_inference import VideoInferenceYolo

# %%
model_path = "../../models/yolo/yolo11m-seg.pt"
model_path_tie = "../../models/yolo/yolo11m-seg.pt"
video_path = "../../data/test_video/test_video.mp4"
target_size = (640, 360)
device = "cuda:0"
out_dir = "./out/"
# matt=True
matt = False
# blur = "GaussianBlur"
blur = ""

# %%
video_inference = VideoInferenceYolo(model_path, target_size, device=device,
                                     model_path_tie=model_path_tie, matt=matt,
                                     blur=blur)

# %%
video_inference.inference_video(video_path, out_dir=out_dir)
# Out:
# 0: 384x640 1 person, 33.1ms
# Speed: 0.0ms preprocess, 33.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.5ms
# Speed: 1.8ms preprocess, 16.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1
#
# 0: 384x640 1 person, 16.1ms
# Speed: 1.9ms preprocess, 16.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.6ms
# Speed: 3.2ms preprocess, 13.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 2
#
# 0: 384x640 1 person, 13.1ms
# Speed: 0.0ms preprocess, 13.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 3
#
# 0: 384x640 1 person, 12.7ms
# Speed: 1.1ms preprocess, 12.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.6ms
# ...
